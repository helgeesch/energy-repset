# %% [markdown]
# # Example 7: Constructive Algorithms
#
# Examples 1--5 all use the **Generate-and-Test** workflow: enumerate candidates, score each one, pick the best. Constructive algorithms work differently — they **build** solutions iteratively using their own internal objectives.
#
# This notebook demonstrates three constructive algorithms:
#
# | Algorithm | Idea | Internal objective | Output |
# |-----------|------|-------------------|--------|
# | **Hull Clustering** | Select periods that span the convex hull of the feature space | Minimize projection error | Subset + blended weights |
# | **CTPC** | Hierarchical clustering that only merges *temporally adjacent* periods | Minimize within-cluster sum of squares | Contiguous segments + segment-size weights |
# | **Snippet** | Greedy selection of multi-day subsequences via p-median | Minimize total distance to nearest snippet | Subsequence starts + assignment-fraction weights |
#
# Because these algorithms have their own built-in objectives, they do not use the `ObjectiveSet` during search — only for optional post-hoc evaluation.

# %%
import pandas as pd
import energy_repset as rep
import energy_repset.diagnostics as diag
import plotly.io as pio; pio.renderers.default = 'notebook_connected'

# %%
url = "https://tubcloud.tu-berlin.de/s/pKttFadrbTKSJKF/download/time-series-lecture-2.csv"
df_raw = pd.read_csv(url, index_col=0, parse_dates=True).rename_axis('variable', axis=1)
df_raw = df_raw.drop('prices', axis=1)

# %% [markdown]
# ---
# ## 1. Hull Clustering
#
# Hull Clustering selects periods that form the vertices of a convex hull enclosing the data in feature space. The intuition: if your representatives span the "boundary" of the data cloud, every other period can be expressed as a convex combination of them — which is exactly what the blended representation model does.
#
# The algorithm greedily adds the period that most reduces the total projection error (i.e., the error from approximating all periods as convex combinations of the selected ones).

# %%
context_monthly = rep.ProblemContext(df_raw=df_raw, slicer=rep.TimeSlicer(unit="month"))

workflow_hull = rep.Workflow(
    feature_engineer=rep.StandardStatsFeatureEngineer(),
    search_algorithm=rep.HullClusteringSearch(k=3, hull_type='convex'),
    representation_model=rep.BlendedRepresentationModel(blend_type='convex'),
)
experiment_hull = rep.RepSetExperiment(context_monthly, workflow_hull)
result_hull = experiment_hull.run()

print(f"Selection:        {result_hull.selection}")
print(f"Projection error: {result_hull.scores['projection_error']:.4f}")
# Out:
# Selection:        (Period('2015-12', 'M'), Period('2015-08', 'M'), Period('2015-11', 'M'))
# Projection error: 170.9117

# %%
# Aggregate blended weights for bar chart
if isinstance(result_hull.weights, pd.DataFrame):
    agg = result_hull.weights.sum(axis=0)
    weights_hull_agg = (agg / agg.sum()).to_dict()
else:
    weights_hull_agg = result_hull.weights

fig = diag.ResponsibilityBars().plot(weights_hull_agg, show_uniform_reference=True)
fig.update_layout(title='Hull Clustering: Responsibility Weights (Blended, Aggregated)')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5452b2bc-6144-4e3c-bca5-cf3ef0959411" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5452b2bc-6144-4e3c-bca5-cf3ef0959411")) {                    Plotly.newPlot(                        "5452b2bc-6144-4e3c-bca5-cf3ef0959411",                        [{"hovertemplate":"slice=%{x}\u003cbr\u003eweight=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"NsSdlE37xz9GOpybuyPhP1ipeP7hutE\u002f"},"textposition":"outside","texttemplate":"%{y:.3f}","x":["2015-12","2015-08","2015-11"],"xaxis":"x","y":{"dtype":"f8","bdata":"NsSdlE37xz9GOpybuyPhP1ipeP7hutE\u002f"},"yaxis":"y","type":"bar"}],                        {"annotations":[{"showarrow":false,"text":"Uniform (0.333)","x":0,"xanchor":"left","xref":"x domain","y":0.3333333333333333,"yanchor":"bottom","yref":"y"}],"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"shapes":[{"line":{"dash":"dot"},"type":"line","x0":0,"x1":1,"xref":"x domain","y0":0.3333333333333333,"y1":0.3333333333333333,"yref":"y"}],"title":{"text":"Hull Clustering: Responsibility Weights (Blended, Aggregated)"},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Selected Period"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"range":[0,0.6159537072327058],"title":{"text":"Responsibility Weight"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parco ...

# %%
feature_ctx_hull = experiment_hull.feature_context
cols = list(feature_ctx_hull.df_features.columns[:2])

fig = diag.FeatureSpaceScatter2D().plot(
    feature_ctx_hull.df_features, x=cols[0], y=cols[1], selection=result_hull.selection
)
fig.update_layout(title='Hull Clustering: Feature Space')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="765a51bd-d67d-4008-8d5b-ce41bd5056a2" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("765a51bd-d67d-4008-8d5b-ce41bd5056a2")) {                    Plotly.newPlot(                        "765a51bd-d67d-4008-8d5b-ce41bd5056a2",                        [{"customdata":[["2015-01"],["2015-02"],["2015-03"],["2015-04"],["2015-05"],["2015-06"],["2015-07"],["2015-09"],["2015-10"]],"hovertemplate":"is_selected=False\u003cbr\u003emean__load=%{x}\u003cbr\u003emean__onwind=%{y}\u003cbr\u003eslice_label=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"lightgray","symbol":"circle"},"mode":"markers","name":"False","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AsdcES1L6T9Aj0vNsUb3P22HYmEsD+s\u002f6sPWBbRJ6r9hXdizMNz5v6JJNkJcqOy\u002fo4LHTwzW0b8mmnkUAsDUv26aGH1Td8c\u002f"},"xaxis":"x","y":{"dtype":"f8","bdata":"cqJeGpT6+T98byB7uM3Gvy0DaPKdZdg\u002fICRvs2tK2r\u002fV+n+AVO\u002fbv4NJGsQfBuy\u002frIewcTGsxb8qHsJq2H\u002fZv1LJ3hG7cvO\u002f"},"yaxis":"y","type":"scatter"},{"customdata":[["2015-08"],["2015-11"],["2015-12"]],"hovertemplate":"is_selected=True\u003cbr\u003emean__load=%{x}\u003cbr\u003emean__onwind=%{y}\u003cbr\u003eslice_label=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"red","symbol":"circle"},"mode":"markers","name":"True","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"hdg4eAYS8L9l+rW54bT3P9r6HcnBqMc\u002f"},"xaxis":"x","y":{"dtype":"f8","bdata":"JlcacXec8r+bBnCxvTv3P3sJ5IEsQPY\u002f"},"yaxis":"y","type":"scatter"}],                        {"hovermode":"closest","legend":{"title":{"text":"is_selected"},"tracegroupgap":0},"margin":{"t":60},"title":{"text":"Hull Clustering: Feature Space"},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"mean__load"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"mean__onwind"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth": ...

# %%
slicer_monthly = rep.TimeSlicer(unit="month")
selected_idx = slicer_monthly.get_indices_for_slice_combi(df_raw.index, result_hull.selection)
df_sel = df_raw.loc[selected_idx]

fig = diag.DistributionOverlayECDF().plot(df_raw['load'], df_sel['load'])
fig.update_layout(title='Hull Clustering: ECDF Overlay (Load)')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="2afc5356-5788-485c-938f-828288e27c1c" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2afc5356-5788-485c-938f-828288e27c1c")) {                    Plotly.newPlot(                        "2afc5356-5788-485c-938f-828288e27c1c",                        [{"line":{"width":2},"mode":"lines","name":"Full","x":{"dtype":"f8","bdata":"L90kBoE1QEAAAAAAAFBAQLbz\u002fdR4aUBAbxKDwMpxQEAUrkfhepRAQFTjpZvEwEBA9ihcj8LFQEAAAAAAANBAQHE9Ctej0EBAhetRuB7VQEA730+Nl95AQCPb+X5q\u002fEBAy6FFtvP9QEAhsHJokQ1BQDEIrBxaFEFAPzVeukkcQUDJdr6fGh9BQCcxCKwcKkFAsHJoke08QUCiRbbz\u002fURBQJzEILBySEFADAIrhxZJQUDHSzeJQVBBQPp+arx0U0FAEFg5tMhWQUA1XrpJDGJBQMP1KFyPYkFAarx0kxhkQUBOYhBYOWRBQC\u002fdJAaBZUFAoBov3SRmQUBI4XoUrmdBQHsUrkfhakFACKwcWmRrQUDD9Shcj3JBQBfZzvdTc0FAFK5H4Xp0QUDZzvdT43VBQPCnxks3eUFAlkOLbOd7QUACK4cW2X5BQPT91HjphkFAnMQgsHKIQUCR7Xw\u002fNY5BQG8Sg8DKkUFAUI2XbhKTQUDdJAaBlZNBQIXrUbgelUFAEoPAyqGVQUBmZmZmZpZBQLbz\u002fdR4mUFArkfhehSeQUAZBFYOLaJBQG3n+6nxokFAMzMzMzOjQUAzMzMzM6NBQBfZzvdTo0FATmIQWDmkQUBI4XoUrqdBQPCnxks3qUFAlkOLbOerQUDByqFFtrNBQKRwPQrXs0FAhetRuB61QUArhxbZzrdBQEJg5dAiu0FACKwcWmS7QUAj2\u002fl+arxBQLByaJHtvEFAkxgEVg69QUCuR+F6F
9QkCuR+F6FP5CQMUgsHJoAUNAi2zn+6kBQ0BvEoPAygFDQN0kBoGVA0NAhxbZzvcDQ0ASg8DKoQVDQNejcD0KB0NADAIrhxYJQ0DTTWIQWAlDQLByaJHtDENAH4XrUbgOQ0DHSzeJQRBDQP7UeOkmEUNANV66SQwSQ0CJQWDl0BJDQE5iEFg5FENAokW28\u002f0UQ0Av3S ...

# %% [markdown]
# ---
# ## 2. CTPC (Chronological Time-Period Clustering)
#
# CTPC is hierarchical agglomerative clustering with a **contiguity constraint**: only temporally adjacent periods can be merged. This guarantees the output is a set of contiguous segments — e.g., "Jan-Mar", "Apr-Jun", etc. — which is useful for models with long-duration storage or seasonal dynamics.
#
# Weights reflect the size of each segment relative to the total.

# %%
workflow_ctpc = rep.Workflow(
    feature_engineer=rep.StandardStatsFeatureEngineer(),
    search_algorithm=rep.CTPCSearch(k=4, linkage='ward'),
)
experiment_ctpc = rep.RepSetExperiment(context_monthly, workflow_ctpc)
result_ctpc = experiment_ctpc.run()

print(f"Selection: {result_ctpc.selection}")
print(f"WCSS:      {result_ctpc.scores['wcss']:.4f}")
print(f"Weights:   { {str(k): round(v, 3) for k, v in result_ctpc.weights.items()} }")

# %%
if 'segments' in result_ctpc.diagnostics:
    print("Contiguous segments:")
    for seg in result_ctpc.diagnostics['segments']:
        print(f"  {seg['start']} -- {seg['end']}  "
              f"(size={seg['size']}, representative={seg['representative']})")
# Out:
# Contiguous segments:
#   2015-01 -- 2015-03  (size=3, representative=2015-03)
#   2015-04 -- 2015-08  (size=5, representative=2015-06)
#   2015-09 -- 2015-10  (size=2, representative=2015-09)
#   2015-11 -- 2015-12  (size=2, representative=2015-11)

# %%
fig = diag.ResponsibilityBars().plot(result_ctpc.weights, show_uniform_reference=True)
fig.update_layout(title='CTPC: Responsibility Weights (Segment Fractions)')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4402e360-bae7-4764-8e36-5753897b196b" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4402e360-bae7-4764-8e36-5753897b196b")) {                    Plotly.newPlot(                        "4402e360-bae7-4764-8e36-5753897b196b",                        [{"hovertemplate":"slice=%{x}\u003cbr\u003eweight=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAAAA0D9VVVVVVVXFP6uqqqqqqto\u002fVVVVVVVVxT8="},"textposition":"outside","texttemplate":"%{y:.3f}","x":["2015-03","2015-11","2015-06","2015-09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA0D9VVVVVVVXFP6uqqqqqqto\u002fVVVVVVVVxT8="},"yaxis":"y","type":"bar"}],                        {"annotations":[{"showarrow":false,"text":"Uniform (0.250)","x":0,"xanchor":"left","xref":"x domain","y":0.25,"yanchor":"bottom","yref":"y"}],"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"shapes":[{"line":{"dash":"dot"},"type":"line","x0":0,"x1":1,"xref":"x domain","y0":0.25,"y1":0.25,"yref":"y"}],"title":{"text":"CTPC: Responsibility Weights (Segment Fractions)"},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Selected Period"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"range":[0,0.47916666666666663],"title":{"text":"Responsibility Weight"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"color ...

# %%
feature_ctx_ctpc = experiment_ctpc.feature_context
cols = list(feature_ctx_ctpc.df_features.columns[:2])

fig = diag.FeatureSpaceScatter2D().plot(
    feature_ctx_ctpc.df_features, x=cols[0], y=cols[1], selection=result_ctpc.selection
)
fig.update_layout(title='CTPC: Feature Space')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f85f3544-3117-4290-ae29-95bacb244a80" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f85f3544-3117-4290-ae29-95bacb244a80")) {                    Plotly.newPlot(                        "f85f3544-3117-4290-ae29-95bacb244a80",                        [{"customdata":[["2015-01"],["2015-02"],["2015-04"],["2015-05"],["2015-07"],["2015-08"],["2015-10"],["2015-12"]],"hovertemplate":"is_selected=False\u003cbr\u003emean__load=%{x}\u003cbr\u003emean__onwind=%{y}\u003cbr\u003eslice_label=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"lightgray","symbol":"circle"},"mode":"markers","name":"False","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AsdcES1L6T9Aj0vNsUb3P+rD1gW0Seq\u002fYV3YszDc+b+jgsdPDNbRv4XYOHgGEvC\u002fbpoYfVN3xz\u002fa+h3JwajHPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"cqJeGpT6+T98byB7uM3GvyAkb7NrStq\u002f1fp\u002fgFTv27+sh7BxMazFvyZXGnF3nPK\u002fUsneEbty8797CeSBLED2Pw=="},"yaxis":"y","type":"scatter"},{"customdata":[["2015-03"],["2015-06"],["2015-09"],["2015-11"]],"hovertemplate":"is_selected=True\u003cbr\u003emean__load=%{x}\u003cbr\u003emean__onwind=%{y}\u003cbr\u003eslice_label=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"red","symbol":"circle"},"mode":"markers","name":"True","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"bYdiYSwP6z+iSTZCXKjsvyaaeRQCwNS\u002fZfq1ueG09z8="},"xaxis":"x","y":{"dtype":"f8","bdata":"LQNo8p1l2D+DSRrEHwbsvyoewmrYf9m\u002fmwZwsb079z8="},"yaxis":"y","type":"scatter"}],                        {"hovermode":"closest","legend":{"title":{"text":"is_selected"},"tracegroupgap":0},"margin":{"t":60},"title":{"text":"CTPC: Feature Space"},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"mean__load"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"mean__onwind"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"col ...

# %%
selected_idx_ctpc = slicer_monthly.get_indices_for_slice_combi(df_raw.index, result_ctpc.selection)
df_sel_ctpc = df_raw.loc[selected_idx_ctpc]

fig = diag.DistributionOverlayECDF().plot(df_raw['load'], df_sel_ctpc['load'])
fig.update_layout(title='CTPC: ECDF Overlay (Load)')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1fe23764-63a1-4b96-9f3b-988abae07a58" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1fe23764-63a1-4b96-9f3b-988abae07a58")) {                    Plotly.newPlot(                        "1fe23764-63a1-4b96-9f3b-988abae07a58",                        [{"line":{"width":2},"mode":"lines","name":"Full","x":{"dtype":"f8","bdata":"L90kBoE1QEAAAAAAAFBAQLbz\u002fdR4aUBAbxKDwMpxQEAUrkfhepRAQFTjpZvEwEBA9ihcj8LFQEAAAAAAANBAQHE9Ctej0EBAhetRuB7VQEA730+Nl95AQCPb+X5q\u002fEBAy6FFtvP9QEAhsHJokQ1BQDEIrBxaFEFAPzVeukkcQUDJdr6fGh9BQCcxCKwcKkFAsHJoke08QUCiRbbz\u002fURBQJzEILBySEFADAIrhxZJQUDHSzeJQVBBQPp+arx0U0FAEFg5tMhWQUA1XrpJDGJBQMP1KFyPYkFAarx0kxhkQUBOYhBYOWRBQC\u002fdJAaBZUFAoBov3SRmQUBI4XoUrmdBQHsUrkfhakFACKwcWmRrQUDD9Shcj3JBQBfZzvdTc0FAFK5H4Xp0QUDZzvdT43VBQPCnxks3eUFAlkOLbOd7QUACK4cW2X5BQPT91HjphkFAnMQgsHKIQUCR7Xw\u002fNY5BQG8Sg8DKkUFAUI2XbhKTQUDdJAaBlZNBQIXrUbgelUFAEoPAyqGVQUBmZmZmZpZBQLbz\u002fdR4mUFArkfhehSeQUAZBFYOLaJBQG3n+6nxokFAMzMzMzOjQUAzMzMzM6NBQBfZzvdTo0FATmIQWDmkQUBI4XoUrqdBQPCnxks3qUFAlkOLbOerQUDByqFFtrNBQKRwPQrXs0FAhetRuB61QUArhxbZzrdBQEJg5dAiu0FACKwcWmS7QUAj2\u002fl+arxBQLByaJHtvEFAkxgEVg69QUCuR+F6FL5BQB+F61G4vkFAj8L1KFy\u002fQUBU46WbxMBBQMUgsHJowUFAw\u002fUoXI\u002fCQUDXo3A9CsdBQNNNYhBYyUFAsp3vp8bLQUA\u002fNV66ScxBQHWTGARWzkFAVg4tsp3PQUCq8dJNYtBBQKjGSzeJ0UFAMQisHFrUQUC+nxov3dRBQIXrUbge1UFAaJHtfD\u002fVQUAOLbKd79dBQCcxCKwc2kFAXI\u002fC9SjcQUDJdr6fGt9BQMHKoUW240FAwcqhRbbjQUDByqFFtuNBQKRwPQrX40FAFK5H4XrkQUCgGi\u002fdJOZBQIPAyqFF5kFAYhBYObToQUCamZmZmelBQJqZmZmZ6UFAYOXQItvpQUBSuB6F6\u002fFB
# %%
context_daily = rep.ProblemContext(df_raw=df_raw, slicer=rep.TimeSlicer(unit="day"))

workflow_snippet = rep.Workflow(
    feature_engineer=rep.DirectProfileFeatureEngineer(),
    search_algorithm=rep.SnippetSearch(k=4, period_length_days=7, step_days=7),
)
experiment_snippet = rep.RepSetExperiment(context_daily, workflow_snippet)
result_snippet = experiment_snippet.run()

print(f"Selection (start days): {result_snippet.selection}")
print(f"Total distance:         {result_snippet.scores['total_distance']:.4f}")
print(f"Weights:                { {str(k): round(v, 3) for k, v in result_snippet.weights.items()} }")

# %%
fig = diag.ResponsibilityBars().plot(result_snippet.weights, show_uniform_reference=True)
fig.update_layout(title='Snippet: Responsibility Weights (Assignment Fractions)')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="18761510-2264-41c1-922a-39aa2374d74f" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("18761510-2264-41c1-922a-39aa2374d74f")) {                    Plotly.newPlot(                        "18761510-2264-41c1-922a-39aa2374d74f",                        [{"hovertemplate":"slice=%{x}\u003cbr\u003eweight=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"Np9xFmDzuT93Uw2BaDfVP9M\u002fGcwx\u002fdM\u002f6QQ9rY1O0D8="},"textposition":"outside","texttemplate":"%{y:.3f}","x":["2015-01-01","2015-08-27","2015-01-29","2015-05-14"],"xaxis":"x","y":{"dtype":"f8","bdata":"Np9xFmDzuT93Uw2BaDfVP9M\u002fGcwx\u002fdM\u002f6QQ9rY1O0D8="},"yaxis":"y","type":"bar"}],                        {"annotations":[{"showarrow":false,"text":"Uniform (0.250)","x":0,"xanchor":"left","xref":"x domain","y":0.25,"yanchor":"bottom","yref":"y"}],"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"shapes":[{"line":{"dash":"dot"},"type":"line","x0":0,"x1":1,"xref":"x domain","y0":0.25,"y1":0.25,"yref":"y"}],"title":{"text":"Snippet: Responsibility Weights (Assignment Fractions)"},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Selected Period"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"range":[0,0.38123287671232875],"title":{"text":"Responsibility Weight"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoord ...

# %%
slicer_daily = rep.TimeSlicer(unit="day")
selected_idx_snippet = slicer_daily.get_indices_for_slice_combi(
    df_raw.index, result_snippet.selection
)
df_sel_snippet = df_raw.loc[selected_idx_snippet]

fig = diag.DistributionOverlayECDF().plot(df_raw['load'], df_sel_snippet['load'])
fig.update_layout(title='Snippet: ECDF Overlay (Load)')
fig.show()
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5ec2a5a4-c256-479c-9ae8-e32fef71ac54" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById
8QgEEJAx0s3iUEQQkAZBFYOLRJCQIlBYOXQEkJAwcqhRbYTQkC6SQwCKxdCQJqZmZmZGUJAJQaBlUMbQkA\\u002fKnx0k1CQkBMN4lBYEVCQPT91HjpRkJADAIrhxZJQkCamZmZmUlCQGDl0CLbSUJAN4lBYOVQQkAZBFYOLVJCQBSuR+F6VEJA2\u002fl+arxUQkCcxCCwclhCQPCnxks3WUJAPzVeuklcQkAv3SQGgWVCQKAaL90kZkJA9P3UeOlmQkDVeOkmMWhCQEa28\u002f3UaEJACKwcWmRrQkCsHFpkO29CQIts5\u002fupcUJA\\u002fKnx0k2yQkAX2c73U7NCQMHKoUW2s0JAaJHtfD+1QkBI4XoUrrdCQGDl0CLbuUJAI9v5fmq8QkBzaJHtfL9CQFTjpZvEwEJAppvEILDCQkCgGi\u002fdJMZCQEoMAiuHxkJAgZVDi2zHQkDRItv5fspCQJhuEoPAykJAXrpJDALLQkA9CtejcM1CQCGwcmiRzUJAc2iR7XzPQkCoxks3idFCQKabxCCw0kJAiUFg5dDSQkDByqFFttNCQHsUrkfh2kJAJQaBlUPbQkBcj8L1KNxCQM3MzMzM3EJA5dAi2\u002fneQkA1XrpJDOJCQGiR7Xw\u002f5UJA2c73U+PlQkAQWDm0yOZCQIGVQ4ts50JA8KfGSzfpQkCYbhKDwOpCQEJg5dAi60JAI9v5fmrsQkCNl24Sg\u002fBCQFTjpZvE8EJAGy\u002fdJAbxQkD+1HjpJvFCQKjGSzeJ8UJA3SQGgZXzQkAxCKwcWvRCQDEIrBxa9EJAZmZmZmb2QkBKDAIrh\u002fZCQJzEILBy+EJARrbz\u002fdT4QkDNzMzMzPxCQJMYBFYO\u002fUJA5\u002fup8dL9QkCuR+F6FP5CQMUgsHJoAUNAi2zn+6kBQ0BvEoPAygFDQN0kBoGVA0NAhxbZzvcDQ0ASg8DKoQVDQNejcD0KB0NADAIrhxYJQ0DTTWIQWAlDQLByaJHtDENAH4XrUbgOQ0DHSzeJQRBDQP7UeOkmEUNANV66SQwSQ0CJQWDl0BJDQE5iEFg5FENAokW28\u002f0UQ0Av3S ...

# %% [markdown]
# ---
# ## Summary
#
# All three constructive algorithms find solutions without evaluating an external objective set. Their internal objectives are tightly coupled to the algorithm mechanics, which makes them fast but less modular than Generate-and-Test.

# %%
print(f"{'Algorithm':<25} {'k':>3} {'Internal Score':>20} {'Value':>10}")
print("-" * 60)
print(f"{'Hull Clustering':<25} {'3':>3} {'projection_error':>20} "
      f"{result_hull.scores['projection_error']:>10.4f}")
print(f"{'CTPC':<25} {'4':>3} {'wcss':>20} "
      f"{result_ctpc.scores['wcss']:>10.4f}")
print(f"{'Snippet':<25} {'4':>3} {'total_distance':>20} "
      f"{result_snippet.scores['total_distance']:>10.4f}")
# Out:
# Algorithm                   k       Internal Score      Value
# ------------------------------------------------------------
# Hull Clustering             3     projection_error   170.9117
# CTPC                        4                 wcss   121.7921
# Snippet                     4       total_distance 21833.6298
